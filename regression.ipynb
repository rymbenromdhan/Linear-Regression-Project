# %% [markdown]
# # Linear Regression of the Salary dataset to predict the trend within the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\DELL\\OneDrive\\Bureau\\v03\\Salary_dataset.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
sns.histplot(df['Salary'], bins=20, color='blue')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salary')
plt.show()

# %%
df.describe(include='all')
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
x = df[['YearsExperience']]
y = df['Salary']

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x)

# %%
print("R-squared:",reg.score(x, y).round(3))
# Out:
# R-squared: 0.957

# %%
print("Coefficient:",reg.coef_[0].round(3))
# Out:
# Coefficient: 9449.962

# %%
print("Intercept:",reg.intercept_.round(3))
# Out:
# Intercept: 24848.204

# %%
plt.title("Salary with Years Experience")
plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.scatter(x, y, alpha = 0.2, color="blue")
plt.plot(x, y_pred, color="black")
plt.show()

# %%
df['Prediction'] = y_pred.round(1)
df['Residual'] = y - y_pred.round(1)
df['Difference%'] = (np.absolute(df['Residual'] / df['Salary'] * 100)).round(2)
df
# Out:
#     Unnamed: 0  YearsExperience    Salary  Prediction  Residual  Difference%
# 0            0              1.2   39344.0     36188.2    3155.8         8.02
# 1            1              1.4   46206.0     38078.2    8127.8        17.59
# 2            2              1.6   37732.0     39968.1   -2236.1         5.93
# 3            3              2.1   43526.0     44693.1   -1167.1         2.68
# 4            4              2.3   39892.0     46583.1   -6691.1        16.77
# 5            5              3.0   56643.0     53198.1    3444.9         6.08
# 6            6              3.1   60151.0     54143.1    6007.9         9.99
# 7            7              3.3   54446.0     56033.1   -1587.1         2.91
# 8            8              3.3   64446.0     56033.1    8412.9        13.05
# 9            9              3.8   57190.0     60758.1   -3568.1         6.24
# 10          10              4.0   63219.0     62648.1     570.9         0.90
# 11          11              4.1   55795.0     63593.0   -7798.0        13.98
# 12          12              4.1   56958.0     63593.0   -6635.0        11.65
# 13          13              4.2   57082.0     64538.0   -7456.0        13.06
# 14          14              4.6   61112.0     68318.0   -7206.0        11.79
# 15          15              5.0   67939.0     72098.0   -4159.0         6.12
# 16          16              5.2   66030.0     73988.0   -7958.0        12.05
# 17          17              5.4   83089.0     75878.0    7211.0         8.68
# 18          18              6.0   81364.0     81548.0    -184.0         0.23
# 19          19              6.1   93941.0     82493.0   11448.0        12.19
# 20          20              6.9   91739.0     90052.9    1686.1         1.84
# 21          21              7.2   98274.0     92887.9    5386.1         5.48
# 22          22              8.0  101303.0    100447.9     855.1         0.84
# 23          23              8.3  113813.0    103282.9   10530.1         9.25
# 24          24              8.8  109432.0    108007.9    1424.1         1.30
# 25          25              9.1  105583.0    110842.9   -5259.9         4.98
# 26          26              9.6  116970.0    115567.8    1402.2         1.20
# 27          27              9.7  112636.0    116512.8   -3876.8         3.44
# 28          28             10.4  122392.0    123127.8    -735.8         0.60
# 29          29             10.6  121873.0    125017.8   -3144.8         2.58

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary     Prediction  \
# count   30.000000        30.000000      30.000000      30.000000
# mean    14.500000         5.413333   76004.000000   76003.996667
# std      8.803408         2.837888   27414.429785   26817.931561
# min      0.000000         1.200000   37732.000000   36188.200000
# 25%      7.250000         3.300000   56721.750000   56033.100000
# 50%     14.500000         4.800000   65238.000000   70208.000000
# 75%     21.750000         7.800000  100545.750000   98557.900000
# max     29.000000        10.600000  122392.000000  125017.800000
#
#            Residual  Difference%
# count     30.000000    30.000000
# mean       0.003333     7.047333
# std     5687.626567     5.174505
# min    -7958.000000     0.230000
# 25%    -4088.450000     2.605000
# 50%     -459.900000     6.100000
# 75%     3372.625000    11.755000
# max    11448.000000    17.590000
